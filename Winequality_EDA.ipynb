# %%
# Import required packages

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\himan\anaconda3\envs\Python_Simple\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# Read the data files

red_wine = pd.read_csv('winequality-red.csv', delimiter=';')
white_wine = pd.read_csv('winequality-white.csv', delimiter=';')

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
# Check stats for dataset

red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
red_wine.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
white_wine.quality.value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# ## Impact of other parameters on wine quality

# %%
#Check the red wine quality based on 'alcohol', 'fixed acidity', 'volatile acidity', 'residual sugar'.

red_wine.groupby('quality').aggregate('mean')[['alcohol', 'fixed acidity', 'volatile acidity', 'residual sugar']]
# Out:
#            alcohol  fixed acidity  volatile acidity  residual sugar
# quality
# 3         9.955000       8.360000          0.884500        2.635000
# 4        10.265094       7.779245          0.693962        2.694340
# 5         9.899706       8.167254          0.577041        2.528855
# 6        10.629519       8.347179          0.497484        2.477194
# 7        11.465913       8.872362          0.403920        2.720603
# 8        12.094444       8.566667          0.423333        2.577778

# %%
#Check the white wine quality based on 'alcohol', 'fixed acidity', 'volatile acidity', 'residual sugar'.

white_wine.groupby('quality').aggregate('mean')[['alcohol', 'fixed acidity', 'volatile acidity', 'residual sugar']]
# Out:
#            alcohol  fixed acidity  volatile acidity  residual sugar
# quality
# 3        10.345000       7.600000          0.333250        6.392500
# 4        10.152454       7.129448          0.381227        4.628221
# 5         9.808840       6.933974          0.302011        7.334969
# 6        10.575372       6.837671          0.260564        6.441606
# 7        11.367936       6.734716          0.262767        5.186477
# 8        11.636000       6.657143          0.277400        5.671429
# 9        12.180000       7.420000          0.298000        4.120000

# %%
# creating a new column representing the wine type
red_wine['wine_type'] = 'red'   
white_wine['wine_type'] = 'white'

# %%
# Create quality labels column using quality values with categories in red wine dataset

red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low' 
                                                          if value <= 5 else 'medium' 
                                                              if value <= 7 else 'high')

# %%
# Create quality labels column using quality values with categories in white wine dataset

white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low' 
                                                              if value <= 5 else 'medium' 
                                                                  if value <= 7 else 'high')

# %%
# Combine both the datasets
wines = pd.concat([red_wine, white_wine])

# %%
wines = wines.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
# Check data size
wines.shape
# Out:
# (6497, 14)

# %%
wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  wine_type             6497 non-null   object
#  13  quality_label         6497 non-null   object
# dtypes: float64(11), int64(1), object(2)
# memory usage: 710.7+ KB

# %%
# Verify the impact of other parameters on wine quality

subset_attributes = ['residual sugar', 'total sulfur dioxide', 'sulphates', 'alcohol', 'volatile acidity', 'quality']
rs = round(red_wine[subset_attributes].describe(),2)
ws = round(white_wine[subset_attributes].describe(),2)
pd.concat([rs, ws], axis=1, keys=['Red Wine Statistics', 'White Wine Statistics'])
# Out:
#       Red Wine Statistics                                          \
#            residual sugar total sulfur dioxide sulphates  alcohol
# count             1599.00              1599.00   1599.00  1599.00
# mean                 2.54                46.47      0.66    10.42
# std                  1.41                32.90      0.17     1.07
# min                  0.90                 6.00      0.33     8.40
# 25%                  1.90                22.00      0.55     9.50
# 50%                  2.20                38.00      0.62    10.20
# 75%                  2.60                62.00      0.73    11.10
# max                 15.50               289.00      2.00    14.90
#
#                                 White Wine Statistics                       \
#       volatile acidity  quality        residual sugar total sulfur dioxide
# count          1599.00  1599.00               4898.00              4898.00
# mean              0.53     5.64                  6.39               138.36
# std               0.18     0.81                  5.07                42.50
# min               0.12     3.00                  0.60                 9.00
# 25%               0.39     5.00                  1.70               108.00
# 50%               0.52     6.00                  5.20               134.00
# 75%               0.64     6.00                  9.90               167.00
# max               1.58     8.00                 65.80               440.00
#
#
#       sulphates  alcohol volatile acidity  quality
# count   4898.00  4898.00          4898.00  4898.00
# mean       0.49    10.51             0.28     5.88
# std        0.11     1.23             0.10     0.89
# min        0.22     8.00             0.08     3.00
# 25%        0.41     9.50             0.21     5.00
# 50%        0.47    10.40             0.26     6.00
# 75%        0.55    11.40             0.32     6.00
# max        1.08    14.20             1.10     9.00

# %%
subset_attributes = ['alcohol', 'volatile acidity', 'pH', 'quality']
ls = round(wines[wines['quality_label'] == 'low'][['alcohol', 'volatile acidity', 'pH', 'quality']].describe(),2)
ms = round(wines[wines['quality_label'] == 'medium'][subset_attributes].describe(),2)
hs = round(wines[wines['quality_label'] == 'high'][subset_attributes].describe(),2)
pd.concat([ls, ms, hs], axis=1, keys=['Low Quality Wine', 'Medium Quality Wine', 'High Quality Wine'])
# Out:
#       Low Quality Wine                                    Medium Quality Wine  \
#                alcohol volatile acidity       pH  quality             alcohol
# count          2384.00          2384.00  2384.00  2384.00             3915.00
# mean              9.87             0.40     3.21     4.88               10.81
# std               0.84             0.19     0.16     0.36                1.20
# min               8.00             0.10     2.74     3.00                8.40
# 25%               9.30             0.26     3.11     5.00                9.80
# 50%               9.60             0.34     3.20     5.00               10.80
# 75%              10.40             0.50     3.31     5.00               11.70
# max              14.90             1.58     3.90     5.00               14.20
#
#                                          High Quality Wine                   \
#       volatile acidity       pH  quality           alcohol volatile acidity
# count          3915.00  3915.00  3915.00            198.00           198.00
# mean              0.31     3.22     6.28             11.69             0.29
# std               0.14     0.16     0.45              1.27             0.12
# min               0.08     2.72     6.00              8.50             0.12
# 25%               0.21     3.11     6.00             11.00             0.21
# 50%               0.27     3.21     6.00             12.00             0.28
# 75%               0.36     3.33     7.00             12.60             0.35
# max               1.04     4.01     7.00             14.00             0.85
#
#
#            pH quality
# count  198.00  198.00
# mean     3.23    8.03
# std      0.16    0.16
# min      2.88    8.00
# 25%      3.13    8.00
# 50%      3.23    8.00
# 75%      3.33    8.00
# max      3.72    9.00

# %%
# Anova test for finding the mean value of alcohole levels across wine samples

from scipy import stats
 
F, p = stats.f_oneway(wines[wines['quality_label'] == 'low']['alcohol'], 
                      wines[wines['quality_label'] == 'medium']['alcohol'], 
                      wines[wines['quality_label'] == 'high']['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 673.0745347231032 	p-value: 2.2715337450621843e-266

# %%
print("{:.2f}".format(2.2715337450621843e-266))
# Out:
# 0.00

# %%
# Anova test for finding the mean ph levels across alcohole wine samples

F, p = stats.f_oneway(wines[wines['quality_label'] == 'low']['pH'], 
                      wines[wines['quality_label'] == 'medium']['pH'], 
                      wines[wines['quality_label'] == 'high']['pH'])
print('\nANOVA test for mean pH levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean pH levels across wine samples with different quality ratings
# F Statistic: 1.2363860803545201 	p-value: 0.2905002779768688

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
f.suptitle('Wine Quality - Alcohol Content/pH', fontsize=14)
f.subplots_adjust(top=0.85, wspace=0.3)

sns.boxplot(x="quality_label", y="alcohol", data=wines, ax=ax1)
ax1.set_xlabel("Wine Quality Class",size = 12,alpha=0.8)
ax1.set_ylabel("Wine Alcohol %",size = 12,alpha=0.8)

sns.boxplot(x="quality_label", y="pH", data=wines, ax=ax2)
ax2.set_xlabel("Wine Quality Class",size = 12,alpha=0.8)
ax2.set_ylabel("Wine pH",size = 12,alpha=0.8)
# Out:
# Text(0, 0.5, 'Wine pH')

# %%
red_wine.hist(bins=15, color='red', edgecolor='black', linewidth=1.0,
              xlabelsize=8, ylabelsize=8, grid=False)    
plt.tight_layout(rect=(0, 0, 1.2, 1.2))   
rt = plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=14)  

white_wine.hist(bins=15, color='white', edgecolor='black', linewidth=1.0,
              xlabelsize=8, ylabelsize=8, grid=False)    
plt.tight_layout(rect=(0, 0, 1.2, 1.2))   
wt = plt.suptitle('White Wine Univariate Plots', x=0.65, y=1.25, fontsize=14)

# %%
fig = plt.figure(figsize = (10,4))
title = fig.suptitle("Residual Sugar Content in Wine", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax1 = fig.add_subplot(1,2, 1)
ax1.set_title("Red Wine")
ax1.set_xlabel("Residual Sugar")
ax1.set_ylabel("Frequency") 
ax1.set_ylim([0, 2500])
ax1.text(8, 1000, r'$\mu$='+str(round(red_wine['residual sugar'].mean(),2)), 
         fontsize=12)
_, _, _ = ax1.hist(red_wine['residual sugar'], color='red', bins=15,
                                    edgecolor='black', linewidth=1)

ax2 = fig.add_subplot(1,2, 2)
ax2.set_title("White Wine")
ax2.set_xlabel("Residual Sugar")
ax2.set_ylabel("Frequency")
ax2.set_ylim([0, 2500])
ax2.text(30, 1000, r'$\mu$='+str(round(white_wine['residual sugar'].mean(),2)), 
         fontsize=12)
_, _, _ = ax2.hist(white_wine['residual sugar'], color='white', bins=15,
                                    edgecolor='black', linewidth=1)

# %% [markdown]
# # Multivariate Analysis

# %%
# Creating a figure and a subplot
f, ax = plt.subplots(figsize=(10, 6))

# Finding Correlation
corr = wines.corr()

# Finding a Heatmap
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
            linewidths=.05)

# Doing some decoration
f.subplots_adjust(top=0.93)
t= f.suptitle('Wine Attributes Correlation Heatmap', fontsize=14)

# %%
# Columns to be compared
cols = ['wine_type', 'quality', 'sulphates', 'volatile acidity']

# Creating the pairplot
pp = sns.pairplot(wines[cols], hue='wine_type', size=1.8, aspect=1.8, 
                  palette={"red": "#FF9999", "white": "#FFE888"},
                  plot_kws=dict(edgecolor="black", linewidth=0.5))

# Decorating the figure
fig = pp.fig 
fig.subplots_adjust(top=0.93, wspace=0.3)
t = fig.suptitle('Wine Attributes Pairwise Plots', fontsize=14)
# Out:
# C:\Users\himan\anaconda3\envs\Python_Simple\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Joint Plot for Red Wine
rj = sns.jointplot(x='quality', y='sulphates', data=red_wine,
                   kind='reg', ylim=(0, 2),  
                   color='red', space=0, size=4.5, ratio=4)

# Defining the ticks on X axis
rj.ax_joint.set_xticks(list(range(3,9)))

# Decoration
fig = rj.fig 
fig.subplots_adjust(top=0.9)
t = fig.suptitle('Red Wine Sulphates - Quality', fontsize=12)

####################################################################################

# Joint Plot for White Wine
wj = sns.jointplot(x='quality', y='sulphates', data=white_wine,
                   kind='reg', ylim=(0, 2),
                   color='#FFE160', space=0, size=4.5, ratio=4)

# Defining the ticks on X axis
wj.ax_joint.set_xticks(list(range(3,10)))

# Decoration
fig = wj.fig 
fig.subplots_adjust(top=0.9)
t = fig.suptitle('White Wine Sulphates - Quality', fontsize=12)
# Out:
# C:\Users\himan\anaconda3\envs\Python_Simple\lib\site-packages\seaborn\axisgrid.py:2272: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\himan\anaconda3\envs\Python_Simple\lib\site-packages\seaborn\axisgrid.py:2272: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Defining Facet Grid
g = sns.FacetGrid(wines, col="wine_type", hue='quality_label', 
                  col_order=['red', 'white'], hue_order=['low', 'medium', 'high'],
                  aspect=1.2, size=3.5, palette=sns.light_palette('navy', 3))

# Putting ScatterPlot on the Facet
g.map(plt.scatter, "volatile acidity", "alcohol", alpha=0.9, 
      edgecolor='white', linewidth=0.5)

# Decoration
fig = g.fig 
fig.subplots_adjust(top=0.8, wspace=0.3)
fig.suptitle('Wine Type - Alcohol - Quality - Acidity', fontsize=14)
l = g.add_legend(title='Wine Quality Class')
# Out:
# C:\Users\himan\anaconda3\envs\Python_Simple\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Defining to axis - subplots
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))
f.suptitle('Wine Type - Quality - Alcohol Content', fontsize=14)

# Defining BoxPlot
sns.boxplot(x="quality", y="alcohol", hue="wine_type",
               data=wines, palette={"red": "red", "white": "white"}, ax=ax1)
ax1.set_xlabel("Wine Quality",size = 12,alpha=0.8)
ax1.set_ylabel("Wine Alcohol %",size = 12,alpha=0.2)

sns.boxplot(x="quality_label", y="alcohol", hue="wine_type",
               data=wines, palette={"red": "red", "white": "white"}, ax=ax2)
ax2.set_xlabel("Wine Quality Class",size = 12,alpha=0.8)
ax2.set_ylabel("Wine Alcohol %",size = 12,alpha=0.8)
l = plt.legend(loc='best', title='Wine Type')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))
f.suptitle('Wine Type - Quality - Acidity', fontsize=14)

sns.violinplot(x="quality", y="volatile acidity", hue="wine_type", 
               data=wines, split=True, inner="quart", linewidth=1.3,
               palette={"red": "#FF9999", "white": "white"}, ax=ax1)
ax1.set_xlabel("Wine Quality",size = 12,alpha=0.8)
ax1.set_ylabel("Wine Fixed Acidity",size = 12,alpha=0.8)

sns.violinplot(x="quality_label", y="volatile acidity", hue="wine_type", 
               data=wines, split=True, inner="quart", linewidth=1.3,
               palette={"red": "#FF9999", "white": "white"}, ax=ax2)
ax2.set_xlabel("Wine Quality Class",size = 12,alpha=0.8)
ax2.set_ylabel("Wine Fixed Acidity",size = 12,alpha=0.8)
l = plt.legend(loc='upper right', title='Wine Type')
